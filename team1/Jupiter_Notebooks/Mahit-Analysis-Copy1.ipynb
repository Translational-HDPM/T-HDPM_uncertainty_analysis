# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
import scipy as sp

# Font
plt.rcParams['font.family']     = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'

# set the style of the axes and the text color
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["font.weight"] = "normal"
plt.rcParams['axes.edgecolor']='#333F4B'
plt.rcParams['axes.linewidth']=1.5
plt.rcParams['xtick.color']='#333F4B'
plt.rcParams['ytick.color']='#333F4B'
plt.rcParams['text.color']='#333F4B'
csfont = {'fontname':'Helvetica','fontsize':18}

# %%
df = pd.read_csv('Analysis-Mahit-Feb-6-new.csv')
df.head(5)
# Out:
#    Unnamed: 0  Filter  MC-Runs  Uncert  Run  Unnamed: 0.1  AD Group Mean  \
# 0           0     800   100000     0.2   33             0    1951.203710
# 1           1     400   100000     0.1   26             0    2081.883245
# 2           2     200   100000     0.2   31             0    2026.037843
# 3           3     200   100000     0.1    8             0    2026.047527
# 4           4     800   100000     0.1   30             0    1951.202389
#
#    AD Group Standard Deviation  NCI Group Mean  NCI Group Standard Deviation
# 0                    69.612191     1463.537566                     52.043362
# 1                    34.722074     1570.860734                     25.988529
# 2                    69.301056     1504.378357                     52.078272
# 3                    34.558087     1504.366463                     25.896999
# 4                    34.663840     1463.297783                     26.008766

# %%
nofilter_u1 = df[(df.Filter == 0) & (df.Uncert == .1)]
nofilter_u2 = df[(df.Filter == 0) & (df.Uncert == .2)]

onefilter_u1 = df[(df.Filter == 100) & (df.Uncert== .1)]
onefilter_u2 = df[(df.Filter == 100) & (df.Uncert == .2)]

twofilter_u1 = df[(df.Filter == 200) & (df.Uncert == .1)]
twofilter_u2 = df[(df.Filter == 200) & (df.Uncert == .2)]

fourfilter_u1 = df[(df.Filter == 400) & (df.Uncert == .1)]
fourfilter_u2 = df[(df.Filter == 400) & (df.Uncert == .2)]

eightfilter_u1 = df[(df.Filter == 800) & (df.Uncert == .1)]
eightfilter_u2 = df[(df.Filter == 800) & (df.Uncert == .2)]

# %%
fig,ax = plt.subplots(figsize = (10,10))
plt.hist(nofilter_u1['AD Group Mean'],label = '10%',alpha = .32)
plt.hist(nofilter_u2['AD Group Mean'],label = '20%',alpha = .32)
plt.legend()
# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('AD Group Mean', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(onefilter_u1['AD Group Mean'],label = '10%',alpha = .32)
plt.hist(onefilter_u2['AD Group Mean'],label = '20%',alpha = .32)


# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('AD Group Mean', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(twofilter_u1['AD Group Mean'],label = '10%',alpha = .32)
plt.hist(twofilter_u2['AD Group Mean'],label = '20%',alpha = .32)


# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('AD Group Mean', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(fourfilter_u1['AD Group Mean'],label = '10%',alpha = .32)
plt.hist(fourfilter_u2['AD Group Mean'],label = '20%',alpha = .32)


# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('AD Group Mean', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(eightfilter_u1['AD Group Mean'],label = '10%',alpha = .32)
plt.hist(eightfilter_u2['AD Group Mean'],label = '20%',alpha = .32)


# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('AD Group Mean', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
fig,ax = plt.subplots(figsize = (10,10))
plt.hist(nofilter_u1['NCI Group Standard Deviation'],label = '10%',alpha = .32)
plt.hist(nofilter_u2['NCI Group Standard Deviation'],label = '20%',alpha = .32)

# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('NCI Group Standard Deviation', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
plt.legend()
# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(onefilter_u1['NCI Group Standard Deviation'],label = '10%',alpha = .32)
plt.hist(onefilter_u2['NCI Group Standard Deviation'],label = '20%',alpha = .32)


# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('NCI Group Standard Deviation', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(twofilter_u1['NCI Group Standard Deviation'],label = '10%',alpha = .32)
plt.hist(twofilter_u2['NCI Group Standard Deviation'],label = '20%',alpha = .32)


# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('NCI Group Standard Deviation', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(fourfilter_u1['NCI Group Standard Deviation'],label = '10%',alpha = .32)
plt.hist(fourfilter_u2['NCI Group Standard Deviation'],label = '20%',alpha = .32)


# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('NCI Group Standard Deviation', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(eightfilter_u1['NCI Group Standard Deviation'],label = '10%',alpha = .32)
plt.hist(eightfilter_u2['NCI Group Standard Deviation'],label = '20%',alpha = .32)


# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('NCI Group Standard Deviation', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

# %%
fig,ax = plt.subplots(figsize = (10,10))
plt.hist(nofilter_u1['AD Group Standard Deviation'],label = '10%',alpha = .32)
plt.hist(nofilter_u2['AD Group Standard Deviation'],label = '20%',alpha = .32)
plt.legend()
# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('AD Group Standard Deviation', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(onefilter_u1['AD Group Standard Deviation'],label = '10%',alpha = .32)
plt.hist(onefilter_u2['AD Group Standard Deviation'],label = '20%',alpha = .32)


# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('AD Group Standard Deviation', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(twofilter_u1['AD Group Standard Deviation'],label = '10%',alpha = .32)
plt.hist(twofilter_u2['AD Group Standard Deviation'],label = '20%',alpha = .32)


# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('AD Group Standard Deviation', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(fourfilter_u1['AD Group Standard Deviation'],label = '10%',alpha = .32)
plt.hist(fourfilter_u2['AD Group Standard Deviation'],label = '20%',alpha = .32)


# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('AD Group Standard Deviation', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(eightfilter_u1['AD Group Standard Deviation'],label = '10%',alpha = .32)
plt.hist(eightfilter_u2['AD Group Standard Deviation'],label = '20%',alpha = .32)


# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('AD Group Standard Deviation', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

# %%
fig,ax = plt.subplots(figsize = (10,10))
plt.hist(nofilter_u1['AD Group Standard Deviation'],label = '10%',alpha = .32)
#plt.hist(nofilter_u2['AD Group Standard Deviation'],label = '20%',alpha = .32)

# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('AD Group Standard Deviation', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

# %%
fsize = 35
ticksize = 25
u1_AD_means = [nofilter_u1.mean()['AD Group Mean'],onefilter_u1.mean()['AD Group Mean'],twofilter_u1.mean()['AD Group Mean'],fourfilter_u1.mean()['AD Group Mean'],eightfilter_u1.mean()['AD Group Mean']]
u2_AD_means = [nofilter_u2.mean()['AD Group Mean'],onefilter_u2.mean()['AD Group Mean'],twofilter_u2.mean()['AD Group Mean'],fourfilter_u2.mean()['AD Group Mean'],eightfilter_u2.mean()['AD Group Mean']]

u1_NCI_means = [nofilter_u1.mean()['NCI Group Mean'],onefilter_u1.mean()['NCI Group Mean'],twofilter_u1.mean()['NCI Group Mean'],fourfilter_u1.mean()['NCI Group Mean'],eightfilter_u1.mean()['NCI Group Mean']]
u2_NCI_means = [nofilter_u2.mean()['NCI Group Mean'],onefilter_u2.mean()['NCI Group Mean'],twofilter_u2.mean()['NCI Group Mean'],fourfilter_u2.mean()['NCI Group Mean'],eightfilter_u2.mean()['NCI Group Mean']]

u1_AD_STD = [nofilter_u1.mean()['AD Group Standard Deviation'],onefilter_u1.mean()['AD Group Standard Deviation'],twofilter_u1.mean()['AD Group Standard Deviation'],fourfilter_u1.mean()['AD Group Standard Deviation'],eightfilter_u1.mean()['AD Group Standard Deviation']]
u2_AD_STD = [nofilter_u2.mean()['AD Group Standard Deviation'],onefilter_u2.mean()['AD Group Standard Deviation'],twofilter_u2.mean()['AD Group Standard Deviation'],fourfilter_u2.mean()['AD Group Standard Deviation'],eightfilter_u2.mean()['AD Group Standard Deviation']]

u1_NCI_STD = [nofilter_u1.mean()['NCI Group Standard Deviation'],onefilter_u1.mean()['NCI Group Standard Deviation'],twofilter_u1.mean()['NCI Group Standard Deviation'],fourfilter_u1.mean()['NCI Group Standard Deviation'],eightfilter_u1.mean()['NCI Group Standard Deviation']]
u2_NCI_STD = [nofilter_u2.mean()['NCI Group Standard Deviation'],onefilter_u2.mean()['NCI Group Standard Deviation'],twofilter_u2.mean()['NCI Group Standard Deviation'],fourfilter_u2.mean()['NCI Group Standard Deviation'],eightfilter_u2.mean()['NCI Group Standard Deviation']]


sizes = [0,100,200,400,800]

fig,ax = plt.subplots(figsize = (10,10))

plt.errorbar(sizes,u1_AD_means,u1_AD_STD)
#plt.errorbar(sizes,u2_AD_means,u2_AD_STD)

# set labels
ax.set_xlabel('Filter', fontsize=fsize, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_ylabel('AD Group Mean', fontsize=fsize, fontweight='black', color = '#333F4B',fontname = 'Arial')


# set axis
tickfont = {'fontname':'Arial','fontsize':ticksize}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)
plt.savefig('AD group - Filter.svg')


fig,ax = plt.subplots(figsize = (10,10))

plt.errorbar(sizes,u1_NCI_means,u1_NCI_STD)
#plt.errorbar(sizes,u2_NCI_means,u2_NCI_STD)

# set labels
ax.set_xlabel('Filter', fontsize=fsize, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_ylabel('NCI Group Mean', fontsize=fsize, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':ticksize}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)
plt.savefig('NCI group - Filter.svg')

# %%
fig,ax = plt.subplots(figsize = (10,10))


frac_AD = np.array(u1_AD_STD)/np.array(u1_AD_means)
frac_NCI = np.array(u1_NCI_STD)/np.array(u1_NCI_means) 
newfrac = (frac_AD+frac_NCI) * np.array(u1_AD_means)/np.array(u1_NCI_means)
plt.errorbar(sizes,np.array(u1_AD_means)/np.array(u1_NCI_means),newfrac)



#plt.errorbar(sizes,u2_AD_means,u2_AD_STD)

# set labels
ax.set_xlabel('Filter', fontsize=fsize, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_ylabel('AD/NCI Group Mean', fontsize=fsize, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':ticksize}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)
plt.savefig('AD over NCI group - Filter.svg')

# %%
newfrac
# Out:
# array([3.5892935 , 0.05077083, 0.04627008, 0.04394772, 0.04728776])

# %%
fig,ax = plt.subplots(figsize = (10,10))
plt.hist(nofilter_u1['NCI Group Mean'],label = '10%',alpha = .32)
plt.hist(nofilter_u2['NCI Group Mean'],label = '20%',alpha = .32)
plt.legend()
# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('NCI Group Mean', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(onefilter_u1['NCI Group Mean'],label = '10%',alpha = .32)
plt.hist(onefilter_u2['NCI Group Mean'],label = '20%',alpha = .32)


# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('NCI Group Mean', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(twofilter_u1['NCI Group Mean'],label = '10%',alpha = .32)
plt.hist(twofilter_u2['NCI Group Mean'],label = '20%',alpha = .32)


# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('NCI Group Mean', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(fourfilter_u1['NCI Group Mean'],label = '10%',alpha = .32)
plt.hist(fourfilter_u2['NCI Group Mean'],label = '20%',alpha = .32)


# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('NCI Group Mean', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(eightfilter_u1['NCI Group Mean'],label = '10%',alpha = .32)
plt.hist(eightfilter_u2['NCI Group Mean'],label = '20%',alpha = .32)


# set labels
ax.set_ylabel('Instances', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('NCI Group Mean', fontsize=25, fontweight='black', color = '#333F4B',fontname = 'Arial')

# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")

# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)
