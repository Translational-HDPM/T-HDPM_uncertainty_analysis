# %% [markdown]
# #### Here we will explore why Dr. Braun's analysis and the work of the Summer team differ

# %%
# Load the data as the Summer team does it. The name of the dataframe will be sDF

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

### Reding csv file containing 243 subjects and their raw TPM counts across 1059 genes
### Source of data
sDF = pd.read_excel(
    "C:/Users/filip/OneDrive/Desktop/Molecular Stethoscope/Summer/ClusterMarkers_1819ADcohort.xlsx",
    sheet_name=1,
)
# setting index row name to the gene id
sDF = sDF.set_index("gene_id")

# %%
sDF.head()
# Out:
#                      11174-r1   11178-r1    11182-r1   11182-r2   11186-r1  \
# gene_id
# ENSG00000079482.12  40.167869  43.221009  102.123100  82.137419  59.941767
# ENSG00000169021.5    4.669515   8.401576    6.827512   9.261443  11.148535
# ENSG00000204160.11  91.808686  52.448546  105.386495  48.958301  32.223227
# ENSG00000106780.8   44.561230   8.633877   19.836541  21.810697   9.518698
# ENSG00000113303.11   3.803395   2.503695   10.826006   3.646693   7.922817
#
#                      11186-r2   11190-r1   11190-r2   11194-r1   11194-r2  \
# gene_id
# ENSG00000079482.12  13.792904  72.000992  56.627618  68.009413  59.382986
# ENSG00000169021.5    4.445162   5.426358   3.210182   9.386716   6.226777
# ENSG00000204160.11  33.497053  29.494519  30.000614  71.504342  32.527289
# ENSG00000106780.8    5.770501   9.937019   4.144054  13.294896  12.279378
# ENSG00000113303.11   0.000000   5.855945   5.544861   8.926236   7.141199
#
# ...

# %%
rDF = pd.read_csv("Transformed AD Dataset Feb 23 for Purdue.csv")

# %%
rDF.head()
# Out:
#   Disease  Isolate ID             gene_id Description         r1         r2  \
# 0      AD        2426  ENSG00000002016.16       RAD52   3.241100   5.921222
# 1      AD        2426  ENSG00000003147.17        ICA1  34.247975  19.480717
# 2      AD        2426  ENSG00000004487.15       KDM1A  29.117113  25.974290
# 3      AD        2426  ENSG00000004766.15       VPS50  10.251166  16.598154
# 4      AD        2426  ENSG00000004809.13    SLC22A16   2.227596   0.270566
#
#          TPM   all_mean     all_sd         z     Coeff
# 0   4.581161   6.492253   9.061651 -0.210899 -0.007079
# 1  26.864346  36.356860  19.847739 -0.478267 -0.023359
# 2  27.545701  27.476950   6.966728  0.009868 -0.049431
# 3  13.424660  16.675052   7.177522 -0.452857 -0.009210
# 4   1.249081   4.114478   4.692319 -0.610657 -0.166043
