# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
# Font
plt.rcParams['font.family']     = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'

# set the style of the axes and the text color
#plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["font.weight"] = "normal"
plt.rcParams['axes.edgecolor']='#333F4B'
plt.rcParams['axes.linewidth']=1.5
plt.rcParams['xtick.color']='#333F4B'
plt.rcParams['ytick.color']='#333F4B'
plt.rcParams['text.color']='#333F4B'
csfont = {'fontname':'Helvetica','fontsize':18}

# %%
sim = pd.read_csv('MC-results-S4/'+'George-MC-sim-svaddadi-0-100000-.1-1-normal-Avg-TPM-smallest-simruns.csv')

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(sim['AD Scores'],bins=50,label = 'AD')
plt.hist(sim['NCI Scores'],bins=50,label = 'NCI')

# set labels
ax.set_ylabel('Instances', fontsize=25 , color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('TPM', fontsize=25, color = '#333F4B',fontname = 'Arial')
plt.legend(title = 'Patient',fontsize = 20)
# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")
plt.plot([0,0],[0,8000])
plt.ylim([0,8000])
# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
sim = pd.read_csv('MC-results-S4/'+'George-MC-sim-svaddadi-0-100000-.1-1-normal-Avg-TPM-smallest-simruns.csv')
sim2 = pd.read_csv('../MC-results-S2/'+'George-MC-sim-svaddadi-0-100000-0.1-1-LHS-Coeff-TPM-smallest-simruns.csv')

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(sim2['AD Scores'],bins=100,label = 'AD - LHS',density = True,color = 'green')
plt.hist(sim2['NCI Scores'],bins=100,label = 'NCI - LHS',density = True,color = 'gray')

plt.hist(sim['AD Scores'],bins=100,label = 'AD - MC',density = True,color='orange',histtype='step')
plt.hist(sim['NCI Scores'],bins=100,label = 'NCI - MC',density = True,color = 'blue',histtype='step')

# set labels
ax.set_ylabel('% of Data', fontsize=25 , color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('TPM', fontsize=25, color = '#333F4B',fontname = 'Arial')
plt.legend(title = 'Patient',fontsize = 20)
# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")
plt.plot([0,0],[0,.02])
plt.ylim([0,.02])
# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

# %%
sim = pd.read_csv('MC-results-S4/'+'George-MC-sim-svaddadi-0-100000-.1-1-normal-Avg-TPM-smallest-simruns.csv')
sim2 = pd.read_csv('../MC-results-S2/'+'George-MC-sim-svaddadi-0-100000-0.1-1-gamma-Coeff-TPM-smallest-simruns.csv')

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(sim2['AD Scores'],bins=50,label = 'AD - gamma',density = True,color = 'green')
plt.hist(sim2['NCI Scores'],bins=50,label = 'NCI - gamma',density = True,color = 'gray')

plt.hist(sim['AD Scores'],bins=50,label = 'AD - MC',density = True,color='orange',histtype='step')
plt.hist(sim['NCI Scores'],bins=50,label = 'NCI - MC',density = True,color = 'blue',histtype='step')

# set labels
ax.set_ylabel('% of Data', fontsize=25 , color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('TPM', fontsize=25, color = '#333F4B',fontname = 'Arial')
plt.legend(title = 'Patient',fontsize = 20)
# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")
plt.plot([0,0],[0,.02])
plt.ylim([0,.02])
# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

# %%
sim = pd.read_csv('MC-results-S4/'+'George-MC-sim-svaddadi-0-100000-.1-1-normal-Avg-TPM-smallest-simruns.csv')
sim2 = pd.read_csv('../MC-results-S2/'+'George-MC-sim-svaddadi-0-100000-0.1-1-rayleigh-Coeff-TPM-smallest-simruns.csv')

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(sim2['AD Scores'],bins=50,label = 'AD - rayleigh',density = True,color = 'green')
plt.hist(sim2['NCI Scores'],bins=50,label = 'NCI - rayleigh',density = True,color = 'gray')

plt.hist(sim['AD Scores'],bins=50,label = 'AD - MC',density = True,color='orange',histtype='step')
plt.hist(sim['NCI Scores'],bins=50,label = 'NCI - MC',density = True,color = 'blue',histtype='step')

# set labels
ax.set_ylabel('% of Data', fontsize=25 , color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('TPM', fontsize=25, color = '#333F4B',fontname = 'Arial')
plt.legend(title = 'Patient',fontsize = 20)
# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")
plt.plot([0,0],[0,.02])
plt.ylim([0,.02])
# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

# %%
sim = pd.read_csv('MC-results-S4/'+'George-MC-sim-svaddadi-0-100000-.1-1-normal-Avg-TPM-smallest-simruns.csv')

files = pd.Series(os.listdir('MC-results-S2'))
files = files[files.str.contains('simruns')]
files.values
# Out:
# array(['George-MC-sim-svaddadi-0-100000-0.1-1-Halton-2-Coeff-TPM-smallest-simruns.csv',
#        'George-MC-sim-svaddadi-0-100000-0.1-1-stripes-sample-Coeff-TPM-smallest-simruns.csv',
#        'George-MC-sim-svaddadi-0-100000-0.1-1-correlation-LHS-Coeff-TPM-smallest-simruns.csv',
#        'George-MC-sim-svaddadi-0-100000-0.1-1-cross-shape-Coeff-TPM-smallest-simruns.csv',
#        'George-MC-sim-svaddadi-0-100000-0.1-1-Centered-correlation-LHS-Coeff-TPM-smallest-simruns.csv',
#        'George-MC-sim-svaddadi-0-100000-0.1-1-maxmin-LHS-Coeff-TPM-smallest-simruns.csv',
#        'George-MC-sim-svaddadi-0-100000-0.1-1-Sobol-1-Coeff-TPM-smallest-simruns.csv',
#        'George-MC-sim-svaddadi-0-100000-0.1-1-cvt-hypercube-Coeff-TPM-smallest-simruns.csv',
#        'George-MC-sim-svaddadi-0-100000-0.1-1-Hammersly-Coeff-TPM-smallest-simruns.csv',
#        'George-MC-sim-svaddadi-0-100000-0.1-1-Ball-Coeff-TPM-smallest-simruns.csv',
# ...

# %%
sim = pd.read_csv('MC-results-S4/'+'George-MC-sim-svaddadi-0-100000-.1-1-normal-Avg-TPM-smallest-simruns.csv')
sim2 = pd.read_csv('MC-results-S2/'+'George-MC-sim-svaddadi-0-100000-0.1-1-Halton-1-Coeff-TPM-smallest-simruns.csv')

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(sim2['AD Scores'],bins=100,label = 'AD - Halton (base)',density = True,color = 'green')
plt.hist(sim2['NCI Scores'],bins=100,label = 'NCI - Halton (base)',density = True,color = 'gray')

plt.hist(sim['AD Scores'],bins=100,label = 'AD - MC',density = True,color='orange',histtype='step')
plt.hist(sim['NCI Scores'],bins=100,label = 'NCI - MC',density = True,color = 'blue',histtype='step')

# set labels
ax.set_ylabel('% of Data', fontsize=25 , color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('TPM', fontsize=25, color = '#333F4B',fontname = 'Arial')
plt.legend(title = 'Patient',fontsize = 20)
# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")
plt.plot([0,0],[0,.2])
plt.ylim([0,.05])
# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

# %%
sim = pd.read_csv('MC-results-S4/'+'George-MC-sim-svaddadi-0-100000-.1-1-normal-Avg-TPM-smallest-simruns.csv')
sim2 = pd.read_csv('MC-results-S2/'+'George-MC-sim-svaddadi-0-100000-0.1-1-Sobol-1-Coeff-TPM-smallest-simruns.csv')

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(sim2['AD Scores'],bins=100,label = 'AD - Sobol (base)',density = True,color = 'green')
plt.hist(sim2['NCI Scores'],bins=100,label = 'NCI - Sobol (base)',density = True,color = 'gray')

plt.hist(sim['AD Scores'],bins=100,label = 'AD - MC',density = True,color='orange',histtype='step')
plt.hist(sim['NCI Scores'],bins=100,label = 'NCI - MC',density = True,color = 'blue',histtype='step')

# set labels
ax.set_ylabel('% of Data', fontsize=25 , color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('TPM', fontsize=25, color = '#333F4B',fontname = 'Arial')
plt.legend(title = 'Patient',fontsize = 20)
# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")
plt.plot([0,0],[0,.2])
plt.ylim([0,.05])
# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

# %%
sim = pd.read_csv('MC-results-S4/'+'George-MC-sim-svaddadi-0-100000-.1-1-normal-Avg-TPM-smallest-simruns.csv')
sim2 = pd.read_csv('MC-results-S2/'+'George-MC-sim-svaddadi-0-100000-0.1-1-stripes-sample-Coeff-TPM-smallest-simruns.csv')

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(sim2['AD Scores'],bins=100,label = 'AD - stripes',density = True,color = 'green')
plt.hist(sim2['NCI Scores'],bins=100,label = 'NCI - stripes',density = True,color = 'gray')

plt.hist(sim['AD Scores'],bins=100,label = 'AD - MC',density = True,color='orange',histtype='step')
plt.hist(sim['NCI Scores'],bins=100,label = 'NCI - MC',density = True,color = 'blue',histtype='step')

# set labels
ax.set_ylabel('% of Data', fontsize=25 , color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('TPM', fontsize=25, color = '#333F4B',fontname = 'Arial')
plt.legend(title = 'Patient',fontsize = 20)
# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")
plt.plot([0,0],[0,.2])
plt.ylim([0,.05])
# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

# %%
sim = pd.read_csv('MC-results-S4/'+'George-MC-sim-svaddadi-0-100000-.1-1-normal-Avg-TPM-smallest-simruns.csv')
sim2 = pd.read_csv('MC-results-S2/'+'George-MC-sim-svaddadi-0-100000-0.1-1-correlation-LHS-Coeff-TPM-smallest-simruns.csv')

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(sim2['AD Scores'],bins=100,label = 'AD - LHS (correlation)',density = True,color = 'green')
plt.hist(sim2['NCI Scores'],bins=100,label = 'NCI - LHS (correlation)',density = True,color = 'gray')

plt.hist(sim['AD Scores'],bins=100,label = 'AD - MC',density = True,color='orange',histtype='step')
plt.hist(sim['NCI Scores'],bins=100,label = 'NCI - MC',density = True,color = 'blue',histtype='step')

# set labels
ax.set_ylabel('% of Data', fontsize=25 , color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('TPM', fontsize=25, color = '#333F4B',fontname = 'Arial')
plt.legend(title = 'Patient',fontsize = 20)
# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")
plt.plot([0,0],[0,.2])
plt.ylim([0,.05])
# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

# %%
sim = pd.read_csv('MC-results-S4/'+'George-MC-sim-svaddadi-0-100000-.1-1-normal-Avg-TPM-smallest-simruns.csv')
sim2 = pd.read_csv('MC-results-S2/'+'George-MC-sim-svaddadi-0-100000-0.1-1-maxmin-LHS-Coeff-TPM-smallest-simruns.csv')

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(sim2['AD Scores'],bins=100,label = 'AD - LHS (maxmin)',density = True,color = 'green')
plt.hist(sim2['NCI Scores'],bins=100,label = 'NCI - LHS (maxmin)',density = True,color = 'gray')

plt.hist(sim['AD Scores'],bins=100,label = 'AD - MC',density = True,color='orange',histtype='step')
plt.hist(sim['NCI Scores'],bins=100,label = 'NCI - MC',density = True,color = 'blue',histtype='step')

# set labels
ax.set_ylabel('% of Data', fontsize=25 , color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('TPM', fontsize=25, color = '#333F4B',fontname = 'Arial')
plt.legend(title = 'Patient',fontsize = 20)
# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")
plt.plot([0,0],[0,.2])
plt.ylim([0,.05])
# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

# %%
sim = pd.read_csv('MC-results-S4/'+'George-MC-sim-svaddadi-0-100000-.1-1-normal-Avg-TPM-smallest-simruns.csv')
sim2 = pd.read_csv('MC-results-S2/'+'George-MC-sim-svaddadi-0-100000-0.1-1-ratio-LHS-Coeff-TPM-smallest-simruns.csv')

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(sim2['AD Scores'],bins=100,label = 'AD - LHS (ratio)',density = True,color = 'green')
plt.hist(sim2['NCI Scores'],bins=100,label = 'NCI - LHS (ratio)',density = True,color = 'gray')

plt.hist(sim['AD Scores'],bins=100,label = 'AD - MC',density = True,color='orange',histtype='step')
plt.hist(sim['NCI Scores'],bins=100,label = 'NCI - MC',density = True,color = 'blue',histtype='step')

# set labels
ax.set_ylabel('% of Data', fontsize=25 , color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('TPM', fontsize=25, color = '#333F4B',fontname = 'Arial')
plt.legend(title = 'Patient',fontsize = 20)
# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")
plt.plot([0,0],[0,.2])
plt.ylim([0,.05])
# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

# %%
sim = pd.read_csv('MC-results-S4/'+'George-MC-sim-svaddadi-0-100000-.1-1-normal-Avg-TPM-smallest-simruns.csv')
sim2 = pd.read_csv('MC-results-S2/'+'George-MC-sim-svaddadi-0-100000-0.1-1-cross-shape-Coeff-TPM-smallest-simruns.csv')

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(sim2['AD Scores'],bins=100,label = 'AD - cross',density = True,color = 'green')
plt.hist(sim2['NCI Scores'],bins=100,label = 'NCI - cross',density = True,color = 'gray')

plt.hist(sim['AD Scores'],bins=100,label = 'AD - MC',density = True,color='orange',histtype='step')
plt.hist(sim['NCI Scores'],bins=100,label = 'NCI - MC',density = True,color = 'blue',histtype='step')

# set labels
ax.set_ylabel('% of Data', fontsize=25 , color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('TPM', fontsize=25, color = '#333F4B',fontname = 'Arial')
plt.legend(title = 'Patient',fontsize = 20)
# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")
plt.plot([0,0],[0,.2])
plt.ylim([0,.05])
# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

# %%
sim = pd.read_csv('MC-results-S4/'+'George-MC-sim-svaddadi-0-100000-.1-1-normal-Avg-TPM-smallest-simruns.csv')
sim2 = pd.read_csv('MC-results-S2/'+'George-MC-sim-svaddadi-0-100000-0.1-1-curve-sample-Coeff-TPM-smallest-simruns.csv')

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(sim2['AD Scores'],bins=100,label = 'AD - curve',density = True,color = 'green')
plt.hist(sim2['NCI Scores'],bins=100,label = 'NCI - curve',density = True,color = 'gray')

plt.hist(sim['AD Scores'],bins=100,label = 'AD - MC',density = True,color='orange',histtype='step')
plt.hist(sim['NCI Scores'],bins=100,label = 'NCI - MC',density = True,color = 'blue',histtype='step')

# set labels
ax.set_ylabel('% of Data', fontsize=25 , color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('TPM', fontsize=25, color = '#333F4B',fontname = 'Arial')
plt.legend(title = 'Patient',fontsize = 20)
# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")
plt.plot([0,0],[0,.2])
plt.ylim([0,.05])
# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

# %%
sim = pd.read_csv('MC-results-S4/'+'George-MC-sim-svaddadi-0-100000-.1-1-normal-Avg-TPM-smallest-simruns.csv')
sim2 = pd.read_csv('MC-results-S2/'+'George-MC-sim-svaddadi-0-100000-0.1-1-cvt-hypercube-Coeff-TPM-smallest-simruns.csv')

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(sim2['AD Scores'],bins=100,label = 'AD - CVT',density = True,color = 'green')
plt.hist(sim2['NCI Scores'],bins=100,label = 'NCI - CVT',density = True,color = 'gray')

plt.hist(sim['AD Scores'],bins=100,label = 'AD - MC',density = True,color='orange',histtype='step')
plt.hist(sim['NCI Scores'],bins=100,label = 'NCI - MC',density = True,color = 'blue',histtype='step')

# set labels
ax.set_ylabel('% of Data', fontsize=25 , color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('TPM', fontsize=25, color = '#333F4B',fontname = 'Arial')
plt.legend(title = 'Patient',fontsize = 20)
# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")
plt.plot([0,0],[0,.2])
plt.ylim([0,.05])
# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

# %%
sim = pd.read_csv('MC-results-S4/'+'George-MC-sim-svaddadi-0-100000-.1-1-normal-Avg-TPM-smallest-simruns.csv')
sim2 = pd.read_csv('MC-results-S2/'+'George-MC-sim-svaddadi-0-100000-0.1-1-multimodal-hypercube-Coeff-TPM-smallest-simruns.csv')

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(sim2['AD Scores'],bins=100,label = 'AD - multimodal',density = True,color = 'green')
plt.hist(sim2['NCI Scores'],bins=100,label = 'NCI - multimodal',density = True,color = 'gray')

plt.hist(sim['AD Scores'],bins=100,label = 'AD - MC',density = True,color='orange',histtype='step')
plt.hist(sim['NCI Scores'],bins=100,label = 'NCI - MC',density = True,color = 'blue',histtype='step')

# set labels
ax.set_ylabel('% of Data', fontsize=25 , color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('TPM', fontsize=25, color = '#333F4B',fontname = 'Arial')
plt.legend(title = 'Patient',fontsize = 20)
# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")
plt.plot([0,0],[0,.2])
plt.ylim([0,.05])
# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

# %%
sim = pd.read_csv('MC-results-S4/'+'George-MC-sim-svaddadi-0-100000-.1-1-normal-Avg-TPM-smallest-simruns.csv')
sim2 = pd.read_csv('MC-results-S2/'+'George-MC-sim-svaddadi-0-100000-0.1-1-uniform-hypercube-Coeff-TPM-smallest-simruns.csv')

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(sim2['AD Scores'],bins=100,label = 'AD - uniform',density = True,color = 'green')
plt.hist(sim2['NCI Scores'],bins=100,label = 'NCI - uniform',density = True,color = 'gray')

plt.hist(sim['AD Scores'],bins=100,label = 'AD - MC',density = True,color='orange',histtype='step')
plt.hist(sim['NCI Scores'],bins=100,label = 'NCI - MC',density = True,color = 'blue',histtype='step')

# set labels
ax.set_ylabel('% of Data', fontsize=25 , color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('TPM', fontsize=25, color = '#333F4B',fontname = 'Arial')
plt.legend(title = 'Patient',fontsize = 20)
# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")
plt.plot([0,0],[0,.2])
plt.ylim([0,.05])
# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

# %%
sim = pd.read_csv('MC-results-S4/'+'George-MC-sim-svaddadi-0-100000-.1-1-normal-Avg-TPM-smallest-simruns.csv')
sim2 = pd.read_csv('MC-results-S2/'+'George-MC-sim-svaddadi-0-100000-0.1-1-Ball-Coeff-TPM-smallest-simruns.csv')

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(sim2['AD Scores'],bins=100,label = 'AD - Ball',density = True,color = 'green')
plt.hist(sim2['NCI Scores'],bins=100,label = 'NCI - Ball',density = True,color = 'gray')

plt.hist(sim['AD Scores'],bins=100,label = 'AD - MC',density = True,color='orange',histtype='step')
plt.hist(sim['NCI Scores'],bins=100,label = 'NCI - MC',density = True,color = 'blue',histtype='step')

# set labels
ax.set_ylabel('% of Data', fontsize=25 , color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('TPM', fontsize=25, color = '#333F4B',fontname = 'Arial')
plt.legend(title = 'Patient',fontsize = 20)
# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")
plt.plot([0,0],[0,.2])
plt.ylim([0,.05])
# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)

# %%
sim = pd.read_csv('MC-results-S4/'+'George-MC-sim-svaddadi-0-100000-.1-1-normal-Avg-TPM-smallest-simruns.csv')
sim2 = pd.read_csv('MC-results-S2/'+'George-MC-sim-svaddadi-0-100000-0.1-1-Grid-2-full-Coeff-TPM-smallest-simruns.csv')

fig,ax = plt.subplots(figsize = (10,10))
plt.hist(sim2['AD Scores'],bins=100,label = 'AD - Ball',density = True,color = 'green')
plt.hist(sim2['NCI Scores'],bins=100,label = 'NCI - Ball',density = True,color = 'gray')

plt.hist(sim['AD Scores'],bins=100,label = 'AD - MC',density = True,color='orange',histtype='step')
plt.hist(sim['NCI Scores'],bins=100,label = 'NCI - MC',density = True,color = 'blue',histtype='step')

# set labels
ax.set_ylabel('% of Data', fontsize=25 , color = '#333F4B',fontname = 'Arial')
ax.set_xlabel('TPM', fontsize=25, color = '#333F4B',fontname = 'Arial')
plt.legend(title = 'Patient',fontsize = 20)
# set axis
tickfont = {'fontname':'Arial','fontsize':16}
plt.yticks(**tickfont)
plt.xticks(**tickfont)
ax.tick_params(axis="y",direction="in")
plt.plot([0,0],[0,.2])
plt.ylim([0,.05])
# set grids
grid_setting = {'linestyle':'--', 'linewidth':2,'alpha':0.4}
plt.grid(which='major', axis='y', **grid_setting)
